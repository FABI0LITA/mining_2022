# %% [markdown]
# <a href="https://colab.research.google.com/github/FABI0LITA/mining_2022/blob/main/ITB_%EC%8B%9C%EA%B0%81%ED%99%94_%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **[시각화1] 데이터의 도시별 불균형 수집**

# %%
#[시각화1]에 사용한 health_city.csv는 
#health.csv에서 결측치가 88개 이상으로 집계된 변수의 열을 제외한 후,
#총 1931개의 데이터 중 도시별 분포를 엑셀의 countif 함수를 통해 추출한 새로운 데이터프레임입니다.

# %matplotlib inline

import pandas as pd
import seaborn as sns
sns.set_style("whitegrid")

#한글깨짐방지 코드가 계속 적용이 안 되어서
#시도명을 영어로 대체했습니다.

from google.colab import drive
drive.mount('/content/drive',force_remount=True)
health_city=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/health_city_eng.csv')
plt.figure(figsize = (40, 40))

sns.barplot(data=health_city, x='city', y='percentage')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **시각화1 분석**
#
# (1) 관찰
#
# :시도별 데이터가 고르게 집계되지 않았다. 특히 경기도와 서울특별시에 집중된 데이터가 사용되었음을 알 수 있다.
#
# (2) 해석
#
# :우리나라를 대표하는 건강 데이터 자료를 수집하기 위해서는 시도별로 균등한 비율의 데이터를 수집해야 할 것이다. 하지만 해당 데이터프레임은 특정 시도의 데이터가 집중적으로 많이 수집되어, 결과적으로 전체 결과에 편향을 줄 수 밖에 없는 구조를 갖고 있다. 특히 경기도와 서울특별시의 데이터가 높은 비중으로 수집됨에 따라 health.csv는 대한민국 전체가 아닌 수도권의 건강 상황을 짙게 반영했음을 알 수 있다. 즉, 주어진 데이터프레임의 표본 설계는 올바르지 않다.**굵은 텍스트**

# %% [markdown]
# *이탤릭체 텍스트*### **[시각화2] 수축기혈압과 이완기혈압 간의 관계**

# %%
# %matplotlib inline

import pandas as pd
import seaborn as sns
sns.set_style("whitegrid")

import matplotlib.pyplot as plt
plt.figure(figsize = (20, 20))

#한글깨짐방지 코드가 계속 적용이 안 되어서
#그래프의 제목, x축, 그리고 y축은 영어로 대체했습니다.

plt.title('Relationship between systolic and diastolic blood pressure')
plt.xlabel('systolic')
plt.ylabel('diastolic blood pressure')

from google.colab import drive
drive.mount('/content/drive',force_remount=True)
health=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/health_updated_2.csv')

sns.scatterplot(data = health, x ='수축기혈압', y ='이완기혈압')
# Out:
# Mounted at /content/drive

# %% [markdown]
# [관찰]
#
# 수축기혈압과 이완기혈압은 양의 상관관계를 갖는 것으로 나타났다.
#
# [해석]
#
# 심장의 수축과 이완 정도는 별개가 아니라, 서로 함께 결부되어 있다는 것을 알 수 있다. 일례로 수축 정도가 큰데 이완 정도가 약한 정도는 없는 것이다. 수축기혈압과 이완기혈합은 함께 기능한다.

# %% [markdown]
# ## **[시각화3] 체중과 허리둘레 간의 관계**

# %%
# %matplotlib inline

import pandas as pd
import seaborn as sns
sns.set_style("whitegrid")

import matplotlib.pyplot as plt
plt.figure(figsize = (20, 20))

from google.colab import drive
drive.mount('/content/drive',force_remount=True)
health=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/health_updated_2.csv')

#한글깨짐방지 코드가 계속 적용이 안 되어서
#그래프의 제목, x축, 그리고 y축은 영어로 대체했습니다.

plt.title('Relationship between weight and waist circumferencee')
plt.xlabel('weight')
plt.ylabel('waist circumference')

sns.lineplot(data = health, x = '체중(5Kg 단위)', y = '허리둘레')
# Out:
# Mounted at /content/drive

# %% [markdown]
# [관찰]
#
# 체중과 허리둘레 간에는 양의 상관성이 나타났다.
#
# [해석]
#
# 체중이 늘어날수록 허리둘레는 그에 비례하여 증가하는 것을 알 수 있다. 이때 그래프의 기울기가 45도에 가까운 것으로 보아 두 변수는 서로 정비례에 가까운 관계에 있다는 것을 알 수 있다.
